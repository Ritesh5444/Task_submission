# %%
import pandas as pd

# %%
df =pd.read_csv(r'C:\Users\RiteshKumar\Desktop\New folder\Data for task 31-07-22\FitBit data.csv')

# %%
pd.to_json('testjson')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\RITESH~1\AppData\Local\Temp/ipykernel_4816/94752299.py in <module>
# ----> 1 pd.to_json('testjson')
#
# ~\Anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'to_json'

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391   04-08-2016       23014      20.389999        20.389999
# 453  8877689391   04-09-2016       16470       8.070000         8.070000
# 454  8877689391   04-10-2016       28497      27.530001        27.530001
# 455  8877689391   04-11-2016       10622       8.060000         8.060000
# 456  8877689391   04-12-2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
df.to_json('Fitbitjson')

# %%
df.dtypes
# Out:
# Id                            int64
# ActivityDate                 object
# TotalSteps                    int64
# TotalDistance               float64
# TrackerDistance             float64
# LoggedActivitiesDistance    float64
# VeryActiveDistance          float64
# ModeratelyActiveDistance    float64
# LightActiveDistance         float64
# SedentaryActiveDistance     float64
# VeryActiveMinutes             int64
# FairlyActiveMinutes           int64
# LightlyActiveMinutes          int64
# SedentaryMinutes              int64
# Calories                      int64
# dtype: object

# %%
#3. convert all the dates avaible in dataset to timestamp format in pandas and in sql you to convert it in date format
df['converted_activiity_date'] = pd.to_datetime(df['ActivityDate'])

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391   04-08-2016       23014      20.389999        20.389999
# 453  8877689391   04-09-2016       16470       8.070000         8.070000
# 454  8877689391   04-10-2016       28497      27.530001        27.530001
# 455  8877689391   04-11-2016       10622       8.060000         8.060000
# 456  8877689391   04-12-2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
#4 . Find out in this data that how many unique id's we have 
len(pd.unique(df['Id']))
# Out:
# 35

# %%
df.head(10)
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
# 5  1503960366    3/30/2016       10970           7.16             7.16
# 6  1503960366    3/31/2016       12256           7.86             7.86
# 7  1503960366   04-01-2016       12262           7.87             7.87
# 8  1503960366   04-02-2016       11248           7.25             7.25
# 9  1503960366   04-03-2016       10016           6.37             6.37
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# ...

# %%
df.describe()
# Out:
#                  Id    TotalSteps  TotalDistance  TrackerDistance  \
# count  4.570000e+02    457.000000     457.000000       457.000000
# mean   4.628595e+09   6546.562363       4.663523         4.609847
# std    2.293781e+09   5398.493064       4.082072         4.068540
# min    1.503960e+09      0.000000       0.000000         0.000000
# 25%    2.347168e+09   1988.000000       1.410000         1.280000
# 50%    4.057193e+09   5986.000000       4.090000         4.090000
# 75%    6.391747e+09  10198.000000       7.160000         7.110000
# max    8.877689e+09  28497.000000      27.530001        27.530001
#
#        LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# count                457.000000          457.000000                457.000000
# mean                   0.179427            1.180897                  0.478643
# std                    0.849232            2.487159                  0.830995
# ...

# %%
df.value_counts('Id')['TotalSteps']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\RITESH~1\AppData\Local\Temp/ipykernel_25916/829030151.py in <module>
# ----> 1 df.value_counts('Id')['TotalSteps']
#
# NameError: name 'df' is not defined

# %%
df.head(3)
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 4.07                      0.0                 33
# 1                 3.91                      0.0                 89
# 2                 3.71                      0.0                 56
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# ...

# %%
df.groupby(['Id', 'ActivityDate']).count()
# Out:
#                          TotalSteps  TotalDistance  TrackerDistance  \
# Id         ActivityDate
# 1503960366 04-01-2016             1              1                1
#            04-02-2016             1              1                1
#            04-03-2016             1              1                1
#            04-04-2016             1              1                1
#            04-05-2016             1              1                1
# ...                             ...            ...              ...
# 8877689391 04-08-2016             1              1                1
#            04-09-2016             1              1                1
#            04-10-2016             1              1                1
#            04-11-2016             1              1                1
#            04-12-2016             1              1                1
#
#                          LoggedActivitiesDistance  VeryActiveDistance  \
# Id         ActivityDate
# ...

# %%
#5 . which id is one of the active id that you have in whole dataset 
#Ans - 4057192912 & 4020332650
df.groupby('Id')['ActivityDate'].count().sort_values(ascending= False)
# Out:
# Id
# 4057192912    32
# 4020332650    32
# 1503960366    19
# 1624580081    19
# 2347167796    15
# 4702921684    15
# 4445114986    15
# 6962181067    14
# 2320127002    12
# 4558609924    12
# 8792009665    12
# 8378563200    12
# 8253242879    12
# 7086361926    12
# 7007744171    12
# 2026352035    12
# 5553957443    12
# 8877689391    12
# 1844505072    12
# 2022484408    12
# 2873212765    12
# 3977333714    12
# 1927972279    12
# 4319703577    12
# 8053475328    11
# 5577150313    11
# 6290855005    10
# 1644430081    10
# 6117666160    10
# 3372868164    10
# 6391747486     9
# 6775888955     9
# 2891001357     8
# 8583815059     8
# 4388161847     8
# Name: ActivityDate, dtype: int64

# %%
df.head(5)
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
df['Total_Active_Time'] = df['VeryActiveMinutes'] + df['FairlyActiveMinutes'] + df['LightlyActiveMinutes']

# %%
df.head(3)
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 4.07                      0.0                 33
# 1                 3.91                      0.0                 89
# 2                 3.71                      0.0                 56
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# ...

# %%
df.groupby('Id')['TotalSteps','TotalDistance','Calories','Total_Active_Time','SedentaryMinutes'].sum().reset_index()
# Out:
# C:\Users\RITESH~1\AppData\Local\Temp/ipykernel_27420/349081647.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Id')['TotalSteps','TotalDistance','Calories','Total_Active_Time','SedentaryMinutes'].sum().reset_index()
#             Id  TotalSteps  TotalDistance  Calories  Total_Active_Time  \
# 0   1503960366      221170     144.540001     34128               5318
# 1   1624580081       80299      52.189999     25705               2325
# 2   1644430081       92748      67.490000     29164               2860
# 3   1844505072       43687      28.880000     19391               1920
# 4   1927972279       26170      18.130000     27048               1360
# 5   2022484408      146099     105.290001     29704               3797
# 6   2026352035       40713      25.240000     16266               2032
# 7   2320127002       37661      25.470000     18385               1535
# ...

# %%
#New Dataframe created to store the data for each Id
data1 = df.groupby('Id')['TotalSteps','TotalDistance','Calories','Total_Active_Time','SedentaryMinutes'].sum().reset_index()
# Out:
# C:\Users\RITESH~1\AppData\Local\Temp/ipykernel_27420/113813279.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data1 = df.groupby('Id')['TotalSteps','TotalDistance','Calories','Total_Active_Time','SedentaryMinutes'].sum().reset_index()

# %%
data1.to_csv('Data1exporttest_080822')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\RITESH~1\AppData\Local\Temp/ipykernel_4816/2097734666.py in <module>
# ----> 1 data1.to_xlsx('Data1exporttest_080822')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'to_xlsx'

# %%
data1.head(4)
# Out:
#            Id  TotalSteps  TotalDistance  Calories  Total_Active_Time  \
# 0  1503960366      221170     144.540001     34128               5318
# 1  1624580081       80299      52.189999     25705               2325
# 2  1644430081       92748      67.490000     29164               2860
# 3  1844505072       43687      28.880000     19391               1920
#
#    SedentaryMinutes
# 0             15387
# 1             24288
# 2             10342
# 3             12424

# %%
#Creation of datafram to store the results and perform operations on it
df1 = pd.DataFrame(data1)

# %%
#6 . how many of them have not logged there activity find out in terms of number of ids 
(df1['Id'].where(df1['TotalSteps'] == 0)).count()
# Out:
# 1

# %%
#7 . Find out who is the laziest person id that we have in dataset 
#Ans - 4388161847
df1[df1['TotalSteps'] == df1['TotalSteps'].min()]['Id']
# Out:
# 16    4388161847
# Name: Id, dtype: int64

# %%
#9. how many person are not a regular person with respect to activity try to find out those 
len(pd.unique(df['Id'].where(df['TotalSteps'] == 0)))
# Out:
# 15

# %%
#10 . who is the thired most active person in this dataset find out those in pandas and in sql both .
df.groupby('Id')['ActivityDate'].count().sort_values(ascending= False)
#Ans - 2347167796 , 4702921684 & 4445114986
# Out:
# Id
# 4057192912    32
# 4020332650    32
# 1503960366    19
# 1624580081    19
# 2347167796    15
# 4702921684    15
# 4445114986    15
# 6962181067    14
# 2320127002    12
# 4558609924    12
# 8792009665    12
# 8378563200    12
# 8253242879    12
# 7086361926    12
# 7007744171    12
# 2026352035    12
# 5553957443    12
# 8877689391    12
# 1844505072    12
# 2022484408    12
# 2873212765    12
# 3977333714    12
# 1927972279    12
# 4319703577    12
# 8053475328    11
# 5577150313    11
# 6290855005    10
# 1644430081    10
# 6117666160    10
# 3372868164    10
# 6391747486     9
# 6775888955     9
# 2891001357     8
# 8583815059     8
# 4388161847     8
# Name: ActivityDate, dtype: int64

# %%
df1.head(5)
# Out:
#            Id  TotalSteps  TotalDistance  Calories  Total_Active_Time  \
# 0  1503960366      221170     144.540001     34128               5318
# 1  1624580081       80299      52.189999     25705               2325
# 2  1644430081       92748      67.490000     29164               2860
# 3  1844505072       43687      28.880000     19391               1920
# 4  1927972279       26170      18.130000     27048               1360
#
#    SedentaryMinutes
# 0             15387
# 1             24288
# 2             10342
# 3             12424
# 4             11435

# %%
#11 . who is the 5th most laziest person avilable in dataset find it out 
df1['TotalSteps'].sort_values(ascending = True,na_position = 'last')
df1[df1['TotalSteps'] == 24364]
#Ans - 8583815059
# Out:
#             Id  TotalSteps  TotalDistance  Calories  Total_Active_Time  \
# 32  8583815059       24364          19.02     19130               1117
#
#     SedentaryMinutes
# 32             10094

# %%
df.head(5)
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
# Data for calories burnt from internet
# Walking 1 km fastly - 100 calories
# Walking 1 km moderately - 
# Walking 1 km slowely - 
#1000 steps burns 50 calories (source  -https://caloriesburnedhq.com/calories-burned-walking/)
#women typically burn about 2,000 calories per day and men burn about 2,500 calories per day.

# %%
#1000 steps burns 50 calories (source  -https://caloriesburnedhq.com/calories-burned-walking/)
#data1['Totalcaloriesburnt'] = (data1['TotalSteps']/1000)*50
#data1['Caloriesbrunedperday'] = data1['Totalcaloriesburnt']/30

# %%
data1.head(4)
# Out:
#            Id  TotalSteps  TotalDistance  Calories  Total_Active_Time  \
# 0  1503960366      221170     144.540001     34128               5318
# 1  1624580081       80299      52.189999     25705               2325
# 2  1644430081       92748      67.490000     29164               2860
# 3  1844505072       43687      28.880000     19391               1920
#
#    SedentaryMinutes  caloriesburnt  Totalcaloriesburnt  Caloriesbrunedperday
# 0             15387       11058.50            11058.50            368.616667
# 1             24288        4014.95             4014.95            133.831667
# 2             10342        4637.40             4637.40            154.580000
# 3             12424        2184.35             2184.35             72.811667

# %%
df1 = pd.DataFrame(data1)

# %%
#df1.drop('caloriesburnt',axis = 1).head(4)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\RITESH~1\AppData\Local\Temp/ipykernel_27420/3834048815.py in <module>
# ----> 1 df1.drop('caloriesburnt',axis = 1).head(4)
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
#df1['calorieintakeperday'] = df1['Calories']/30

# %%
df1.head(4)
# Out:
#            Id  TotalSteps  TotalDistance  Calories  Total_Active_Time  \
# 0  1503960366      221170     144.540001     34128               5318
# 1  1624580081       80299      52.189999     25705               2325
# 2  1644430081       92748      67.490000     29164               2860
# 3  1844505072       43687      28.880000     19391               1920
#
#    SedentaryMinutes  Totalcaloriesburnt  Caloriesbrunedperday  \
# 0             15387            11058.50            368.616667
# 1             24288             4014.95            133.831667
# 2             10342             4637.40            154.580000
# 3             12424             2184.35             72.811667
#
#    calorieintakeperday
# 0          1137.600000
# 1           856.833333
# 2           972.133333
# 3           646.366667

# %%
#df1['Caloriesleftperday'] = df1['calorieintakeperday'] - df1['Caloriesbrunedperday']

# %%
#df1.drop('MaintainanceCalories',axis =1, inplace = True)

# %%
#df1 = df1.drop('Caloriesleftperday',axis = 1)

# %%
df.head(4)
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 4.07                      0.0                 33
# 1                 3.91                      0.0                 89
# ...

# %%
#1000 steps burns 50 calories (source  -https://caloriesburnedhq.com/calories-burned-walking/)
df['caloriesburnt'] = (df['TotalSteps']/1000)*50

# %%
df.head(4)
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 4.07                      0.0                 33
# 1                 3.91                      0.0                 89
# ...

# %%
df['Caloriesleft'] = df['Calories'] - df['caloriesburnt']

# %%
df.head(4)
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 4.07                      0.0                 33
# 1                 3.91                      0.0                 89
# ...

# %%
#8 . Explore over an internet that how much calories burn is required for a healthy person and find out how many healthy person we have in our dataset


#As a general guideline, women typically burn about 2,000 calories per day and men burn about 2,500 calories per day. (Source - https://www.nike.com/a/how-many-calories-should-you-burn-daily)
df[df['caloriesburnt'] == 2500]
#Ans - Zero person
# Out:
# Empty DataFrame
# Columns: [Id, ActivityDate, TotalSteps, TotalDistance, TrackerDistance, LoggedActivitiesDistance, VeryActiveDistance, ModeratelyActiveDistance, LightActiveDistance, SedentaryActiveDistance, VeryActiveMinutes, FairlyActiveMinutes, LightlyActiveMinutes, SedentaryMinutes, Calories, Total_Active_Time, caloriesburnt, Caloriesleft]
# Index: []

# %%
#12 . what is a totla acumulative calories burn for a person find out 
df.groupby('Id')['caloriesburnt'].sum()
# Out:
# Id
# 1503960366    11058.50
# 1624580081     4014.95
# 1644430081     4637.40
# 1844505072     2184.35
# 1927972279     1308.50
# 2022484408     7304.95
# 2026352035     2035.65
# 2320127002     1883.05
# 2347167796     7350.05
# 2873212765     3981.95
# 2891001357      309.45
# 3372868164     3063.75
# 3977333714     5198.35
# 4020332650     9242.55
# 4057192912     3019.55
# 4319703577     4692.35
# 4388161847        0.00
# 4445114986     3219.80
# 4558609924     3471.15
# 4702921684     5957.55
# 5553957443     5012.85
# 5577150313     4734.50
# 6117666160     4124.30
# 6290855005      809.05
# 6391747486      601.60
# 6775888955     2501.55
# 6962181067     8847.80
# 7007744171     7356.20
# 7086361926     3662.35
# 8053475328     8164.40
# 8253242879     1433.95
# 8378563200     4881.15
# 8583815059     1218.20
# 8792009665     1856.95
# 8877689391    10450.25
# Name: caloriesburnt, dtype: float64
